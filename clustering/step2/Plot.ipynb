# %%
#import the necessary libraries
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
from pandas import DataFrame
from sklearn.cluster import KMeans


df = pd.read_csv('data1Boundry.csv')
df['text'] = 'cluster ' + df['cluster'].astype(str)
df = DataFrame(data_2[0])
df[1]= data_2[1]

#Plotting For K = 2 For deviceStatus
KMeans_2 = KMeans(n_clusters=2).fit(df)
centroids_2 = KMeans_2.cluster_centers_
centroidsDataset_2 = pd.DataFrame({'lat': centroids_2[:,0],'lon':centroids_2[:,1]})

fig = go.Figure(
        data=go.Scattergeo(
        lon = df[1],
        lat = df[0],
        mode = 'markers',
        # name= "a",
        marker = dict(
                size = 3,
                opacity = 0.2,
                color = 'green',
                ),
        )
    )
fig.add_trace(go.Scattergeo(
        lon = centroidsDataset_2['lon'],
        lat = centroidsDataset_2['lat'],
        #text = cdf['text'],
        mode = 'markers',
        name= "a",
        marker = dict(
                size = 7,
                opacity = 1,
                color = 'Red',
                ),
        )
)

fig.update_layout(
        title = 'Final Project ',
        #geo_scope='usa',
    )


#K = 3 for synthetic data
cdf = pd.read_csv('centerData.csv')
data_2 = pd.read_csv('lat_longs-2.txt',delimiter="\s+", header=None)
df_2 = DataFrame(data_2[0])
df_2[1]= data_2[1]
KMeans_3 = KMeans(n_clusters=3).fit(df_2)
centroids_3 = KMeans_3.cluster_centers_
centroidsDataset_3 = pd.DataFrame({'lat': centroids_3[:,0],'lon':centroids_3[:,1]})
fig = go.Figure(
        data=go.Scattergeo(
        lon = df_2[1],
        lat = df_2[0],
        mode = 'markers',
        # name= "a",
        marker = dict(
                size = 3,
                opacity = 0.2,
                color = 'green',
                ),
        )
    )
fig.add_trace(go.Scattergeo(
        lon = centroidsDataset_3['lon'],
        lat = centroidsDataset_3['lat'],
        #text = cdf['text'],
        mode = 'markers',
        name= "a",
        marker = dict(
                size = 7,
                opacity = 1,
                color = 'Red',
                ),
        )
)

fig.update_layout(
        title = 'Final Project ',
        #geo_scope='usa',
    )


#k = 10 for dbpedia
kmeans_6 = KMeans(n_clusters = 10).fit(df_2)
centroids_6 = kmeans_6.cluster_centers_
print(type(centroids_6))
centroidsDataset_6 = pd.DataFrame({'lat': centroids_6[:,0],'lon':centroids_6[:,1]})

fig = go.Figure(
        data=go.Scattergeo(
        lon = df_2[1],
        lat = df_2[0],
        mode = 'markers',
        # name= "a",
        marker = dict(
                size = 3,
                opacity = 0.2,
                color = 'green',
                ),
        )
    )
fig.add_trace(go.Scattergeo(
        lon = centroidsDataset_6['lon'],
        lat = centroidsDataset_6['lat'],
        #text = cdf['text'],
        mode = 'markers',
        name= "a",
        marker = dict(
                size = 7,
                opacity = 1,
                color = 'Red',
                ),
        )
)

fig.update_layout(
        title = 'Final Project ',
        #geo_scope='usa',
    )
#K = 2 DBPedia 
kmeans_2 = KMeans(n_clusters = 2).fit(df_2)
centroids_2 = kmeans_2.cluster_centers_
print(type(centroids_2))
centroidsDataset_2 = pd.DataFrame({'lat': centroids_2[:,0],'lon':centroids_2[:,1]})


fig = go.Figure(
        data=go.Scattergeo(
        lon = data_2[1],
        lat = data_2[0],
        mode = 'markers',
        # name= "a",
        marker = dict(
                size = 3,
                opacity = 0.2,
                color = 'green',
                ),
        )
    )
fig.add_trace(go.Scattergeo(
        lon = centroidsDataset_6['lon'],
        lat = centroidsDataset_6['lat'],
        #text = cdf['text'],
        mode = 'markers',
        name= "a",
        marker = dict(
                size = 7,
                opacity = 1,
                color = 'Red',
                ),
        )
)

fig.update_layout(
        title = 'Final Project ',
        #geo_scope='usa',
    )










data_1 = pd.read_csv('sample_geo-2.txt',delimiter="\s+", header=None)
data_1 = data_1.iloc[1:]

data = pd.read_csv('cleaned_deviceStatus-2.txt',delimiter=",", header=None)
df = DataFrame(data[0])
df[1] = data[1]
df_1 = DataFrame(data_1[0])
df_1[1] = data_1[1]
print(df_1)
kmeans = KMeans(n_clusters = 5).fit(df)
centroids = kmeans.cluster_centers_
print(type(centroids))
centroidsDataset = pd.DataFrame({'lat': centroids[:,0],'lon':centroids[:,1]})
print(centroidsDataset)
#k-means clustering for k=4 for Synthetic Location
SyntheticLocationKmeans = KMeans(n_clusters = 4).fit(df_1)
centroidsForLocation = SyntheticLocationKmeans.cluster_centers_
centroidsForLocationDS = pd.DataFrame({'lat': centroidsForLocation[:,0],'lon':centroidsForLocation[:,1]})
print(type(centroidsForLocation))


fig = go.Figure(
        data=go.Scattergeo(
        lon = data_2[1],
        lat = data_2[0],
        mode = 'markers',
        # name= "a",
        marker = dict(
                size = 3,
                opacity = 0.2,
                color = 'green',
                ),
        )
    )
fig.add_trace(go.Scattergeo(
        lon = centroidsDataset_6['lon'],
        lat = centroidsDataset_6['lat'],
        #text = cdf['text'],
        mode = 'markers',
        name= "a",
        marker = dict(
                size = 7,
                opacity = 1,
                color = 'Red',
                ),
        )
)

fig.update_layout(
        title = 'Final Project ',
        #geo_scope='usa',
    )
fig.show()
